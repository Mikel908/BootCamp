# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient
# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Notebook3\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(
    q="Bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Fetch the Ethereum news articles
ether_headlines = newsapi.get_everything(
    q="Ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-06-03  New York lawmakers have passed a bill\r\n that...   -0.5574
# 1  2022-06-09  Rapper and entrepreneur Shawn Carter, better k...    0.4404
# 2  2022-06-08  A new study on bitcoin calls into question whe...    0.5267
# 3  2022-06-05  Image caption, President Faustin-Archange Toua...    0.5106
# 4  2022-06-02  You can now reportedly pay for your burritos a...   -0.1027
#
#    positive  negative  neutral
# 0     0.000     0.098    0.902
# 1     0.077     0.000    0.923
# 2     0.124     0.000    0.876
# 3     0.164     0.000    0.836
# 4     0.000     0.040    0.960

# %%
# Create the Ethereum sentiment scores DataFrame
ether_sentiments = []

for article in ether_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ether_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ether_df = pd.DataFrame(ether_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ether_df = ether_df[cols]

ether_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-05-23  GameStop has officially thrown itself headlong...   -0.1027
# 1  2022-05-23  GameStop is going all-in on crypto. The video ...    0.1280
# 2  2022-06-07  The ability to conduct external transfers on P...    0.3182
# 3  2022-06-09  A decentralized autonomous organization, or DA...    0.5859
# 4  2022-06-09  Crypto Winter It May Be, But Ethereum Looks Li...    0.3612
#
#    positive  negative  neutral
# 0     0.000     0.040    0.960
# 1     0.046     0.000    0.954
# 2     0.059     0.000    0.941
# 3     0.134     0.000    0.866
# 4     0.081     0.044    0.875

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean    -0.033550    0.060650    0.068910    0.870450
# std      0.451947    0.062632    0.079504    0.087964
# min     -0.948500    0.000000    0.000000    0.628000
# 25%     -0.381800    0.000000    0.000000    0.826000
# 50%      0.000000    0.060000    0.064000    0.875000
# 75%      0.318200    0.094500    0.101500    0.927500
# max      0.817600    0.262000    0.372000    1.000000

# %%
# Describe the Ethereum Sentiment
ether_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.017831    0.072350    0.063070    0.864580
# std      0.483854    0.076237    0.076434    0.094535
# min     -0.948500    0.000000    0.000000    0.604000
# 25%     -0.394400    0.000000    0.000000    0.810500
# 50%      0.000000    0.058500    0.045000    0.875000
# 75%      0.406800    0.105500    0.098500    0.934250
# max      0.916900    0.349000    0.372000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
wnl = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Complete the tokenizer function
def tokenizer(text):
      
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z]")
    clean = regex.sub(' ', text) 
    # Create a tokenized list of the words
    words = word_tokenize(clean)
    
    # Lemmatize words into root words
    result = [wnl.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    # Remove the stop words
    tokens = [word.lower() for word in result if word.lower() not in sw]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_df["Tokens"] = bitcoin_df.text.apply(tokenizer)
bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-06-03  New York lawmakers have passed a bill\r\n that...   -0.5574
# 1  2022-06-09  Rapper and entrepreneur Shawn Carter, better k...    0.4404
# 2  2022-06-08  A new study on bitcoin calls into question whe...    0.5267
# 3  2022-06-05  Image caption, President Faustin-Archange Toua...    0.5106
# 4  2022-06-02  You can now reportedly pay for your burritos a...   -0.1027
#
#    positive  negative  neutral  \
# 0     0.000     0.098    0.902
# 1     0.077     0.000    0.923
# 2     0.124     0.000    0.876
# 3     0.164     0.000    0.836
# 4     0.000     0.040    0.960
#
#                                               Tokens
# 0  [new, york, lawmaker, passed, bill, would, tem...
# 1  [rapper, entrepreneur, shawn, carter, better, ...
# 2  [new, study, bitcoin, call, question, whether,...
# 3  [image, caption, president, faustin, archange,...
# 4  [reportedly, pay, burrito, taco, bitcoin, digi...

# %%
# Create a new tokens column for Ethereum
ether_df["Tokens"] = ether_df.text.apply(tokenizer)
ether_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-05-23  GameStop has officially thrown itself headlong...   -0.1027
# 1  2022-05-23  GameStop is going all-in on crypto. The video ...    0.1280
# 2  2022-06-07  The ability to conduct external transfers on P...    0.3182
# 3  2022-06-09  A decentralized autonomous organization, or DA...    0.5859
# 4  2022-06-09  Crypto Winter It May Be, But Ethereum Looks Li...    0.3612
#
#    positive  negative  neutral  \
# 0     0.000     0.040    0.960
# 1     0.046     0.000    0.954
# 2     0.059     0.000    0.941
# 3     0.134     0.000    0.866
# 4     0.081     0.044    0.875
#
#                                               Tokens
# 0  [gamestop, ha, officially, thrown, headlong, w...
# 1  [gamestop, going, crypto, video, game, retaile...
# 2  [ability, conduct, external, transfer, paypal,...
# 3  [decentralized, autonomous, organization, dao,...
# 4  [crypto, winter, may, ethereum, looks, like, b...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
N = 2
grams = ngrams(tokenizer(bitcoin_df.text.str.cat()), N)
Counter(grams).most_common(15)
# Out:
# [(('may', 'reuters'), 26),
#  (('new', 'york'), 8),
#  (('june', 'reuters'), 7),
#  (('digital', 'currency'), 6),
#  (('char', 'may'), 6),
#  (('char', 'posted'), 5),
#  (('char', 'june'), 5),
#  (('hong', 'kong'), 4),
#  (('record', 'losing'), 4),
#  (('losing', 'streak'), 4),
#  (('called', 'stablecoin'), 4),
#  (('crypto', 'asset'), 4),
#  (('char', 'london'), 4),
#  (('cryptocurrency', 'market'), 4),
#  (('crypto', 'market'), 4)]

# %%
# Generate the Ethereum N-grams where N=2
N = 2
grams = ngrams(tokenizer(ether_df.text.str.cat()), N)
Counter(grams).most_common(15)
# Out:
# [(('ethereum', 'eth'), 9),
#  (('crypto', 'market'), 7),
#  (('cryptocurrency', 'market'), 6),
#  (('char', 'happened'), 6),
#  (('crypto', 'winter'), 5),
#  (('may', 'reuters'), 5),
#  (('last', 'week'), 5),
#  (('char', 'crypto'), 4),
#  (('char', 'cryptocurrency'), 4),
#  (('eth', 'ha'), 4),
#  (('price', 'ethereum'), 3),
#  (('char', 'new'), 3),
#  (('new', 'york'), 3),
#  (('char', 'may'), 3),
#  (('world', 'biggest'), 3)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
btc_tokens= tokenizer(bitcoin_df.text.str.cat())
token_count(btc_tokens, N=10)
# Out:
# [('char', 96),
#  ('bitcoin', 50),
#  ('reuters', 36),
#  ('crypto', 32),
#  ('cryptocurrency', 30),
#  ('may', 29),
#  ('ha', 28),
#  ('market', 21),
#  ('week', 19),
#  ('new', 18)]

# %%
# Use token_count to get the top 10 words for Ethereum
ether_tokens= tokenizer(ether_df.text.str.cat())
token_count(ether_tokens, N=10)
# Out:
# [('char', 99),
#  ('crypto', 46),
#  ('ha', 33),
#  ('cryptocurrency', 29),
#  ('market', 24),
#  ('ethereum', 20),
#  ('bitcoin', 19),
#  ('wa', 17),
#  ('world', 15),
#  ('token', 13)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
def wordcloud(text, title=""):
    df_cloud = WordCloud(width=500, colormap='RdYlBu').generate(text)
    plt.imshow(df_cloud)
    plt.axis("off")
    fontdict = {"fontsize": 48, "fontweight" : "bold"}
    plt.title(title, fontdict=fontdict)
    plt.show()

# %%
# Generate the Ethereum word cloud
wordcloud(ether_df.text.str.cat(), title='Ethereum Wordcloud')

# %%
# Generate the Bitcoin word cloud
wordcloud(bitcoin_df.text.str.cat(), title='Bitcoin Wordcloud')

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
bct_text = ' '.join(bitcoin_df.text)
bct_text
# Out:
# 'New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It\'s now bound for the desk of… [+2036 chars] Rapper and entrepreneur Shawn Carter, better known as Jay-Z, is bringing Bitcoin to the place where he grew up. On Thursday, Jay-Z and former Twitter CEO Jack Dorsey announced the launch of Bitcoin A… [+2920 chars] A new study on bitcoin calls into question whether the digital currency is truly as decentralized and anonymous as its biggest devotees would have you believe. \r\n Researchers from Baylor, Rice, and t… [+7343 chars] Image caption, President Faustin-Archange Touadéra wants to rethink his country\'s economic philosophy\r\nThe Central African Republic\'s decision to adopt Bitcoin as legal tender came as a surprise to m… [+8881 chars] You can now reportedly pay for your burritos and tacos with Bitcoin and other digital currencies, in case you don\'t mind spending your coins directly instead of going through exchanges first. Flexa h… [+1428 chars] As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of nearly three feet of snow. You can guess how well that … [+3390 chars] Customers at Chipotle will now be able to pay for their burritos with cryptocurrencies, including bitcoin, ether, and dogecoin, in a move that could help crypto become more mainstream, according to t… [+3130 chars] Photo Illustration by Grayson Blackmon / The Verge; Photo by Oliyarnyk / CC-BY-SA-4.0\r\n\n \n\n\n With Michael Chobanian, the president of the Blockchain Association of Ukraine The terrible, unprovoked wa… [+52103 chars] Posted \r\nFrom Bitcoin\'s dramatic drop to a new way to pay for your luxury Gucci handbag, we round up the week\'s big stories in cryptocurrencies. Kristy Kilburn reports. May 11 (Reuters) - Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 40.4% fro… [+361 chars] June 6 (Reuters) - Bitcoin rose 5.2% to $31,441.76 at 2000 GMT on Monday, adding $1,552.78 to its previous close.\r\nThe world\'s biggest and best-known cryptocurrency is down 34.8% from the year\'s high… [+335 chars] At a Mexican restaurant in North London a few weeks ago, a handful of small-time but remarkably discerning retail cryptocurrency investors predicted that terra and luna would crash. Several of them w… [+2779 chars] May 24 (Reuters) - The crypto winter is into its ninth week and bitcoin can\'t shake the chills.\r\nFrom technicals to turnover, market indicators are flashing red or amber for the biggest cryptocurrenc… [+3967 chars] Terra launched a new blockchain with a new luna token, today. Seth Green\'s animated show starring his stolen NFT is up in the air. The largest stablecoin issuer in the world launched a token for the … [+3854 chars] After two linked cryptocurrencies collapsed and became almost worthless, a plan emerged to create a new blockchain for the luna cryptocurrency. Seth Green\'s NFTs were stolen in a phishing scam. Nike … [+3932 chars] Terra is launching a new blockchain with a new luna token. Seth Green\'s animated show starring his stolen NFT is up in the air. The largest stablecoin issuer in the world launched a token for the Mex… [+3792 chars] Sam Bankman-Fried, founder of the digital asset exchange FTX, said the proof of work system of validating blockchain transactions, which underpins bitcoin, was not capable of scaling up to cope with … [+1063 chars] As cryptocurrencies have grown in value, Bitcoin mining has become a major industry. There are publicly traded crypto mining companies like Riot Blockchain and Marathon Digital Holdings, worth hundre… [+2001 chars] To its evangelists, bitcoin is a frictionless, empowering form of money that liberates citizens of the world from the shackles of banks and n ...

# %%
# Run the NER processor on all of the text
bct_doc = nlp(bct_text)


# Add a title to the document
bct_doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bct_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br> mining operations. Early on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , state senators voted
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     36-27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  to pass the legislation. It's now bound for the desk of… [+2036 chars]
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rapper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  and entrepreneur
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shawn Carter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , better known as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jay-Z
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , is bringing Bitcoin to the place where he grew up. On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jay-Z
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and former Twitter CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jack Dorsey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br> Researchers from Baylor, Rice, and t… [+7343 chars] Image caption, President
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Faustin-Archange Touadéra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Central African Republic's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  decision to adopt
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  as legal tender came as a surprise to m… [+8881 chars] You can now reportedly pay for your burritos and tacos with Bitcoin and other digital currencies, in case you don't mind spending your coins directly instead of going through exchanges
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# . Flexa h… [+1428 chars] As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly three feet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  of snow. You can guess how well that … [+3390 chars] Customers at Chipotle will now be able to pay for their burritos with cryptocurrencies, including bitcoin, ether, and dogecoin, in a move that could help crypto become more mainstream, according to t… [+3130 chars
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ] Photo Illustration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grayson Blackmon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The Verge; Photo by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oliyarnyk / CC-BY-SA-4.0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br> </br></br></br> With
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael Chobanian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the president of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Blockchain Association of Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's dramatic drop to a new way to pay for your luxury
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gucci handbag
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , we round up the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     week
#     <span style="font-size: 0.8e

# %%
# List all Entities
for ent in bct_doc.ents:
    print(ent.text + ' ' + ent.label_)
# Out:
# New York GPE
# Friday DATE
# 36-27 CARDINAL
# Rapper NORP
# Shawn Carter PERSON
# Jay-Z PERSON
# Thursday DATE
# Jay-Z PERSON
# Jack Dorsey PERSON
# Faustin-Archange Touadéra LAW
# The Central African Republic's ORG
# Bitcoin NORP
# first ORDINAL
# nearly three feet QUANTITY
# ] Photo Illustration WORK_OF_ART
# Grayson Blackmon PERSON
# Oliyarnyk / CC-BY-SA-4.0 ORG
# Michael Chobanian PERSON
# the Blockchain Association of Ukraine ORG
# Bitcoin ORG
# Gucci handbag PERSON
# week DATE
# Kristy Kilburn PERSON
# May 11 DATE
# Reuters ORG
# 7.23% PERCENT
# 28,758.29 MONEY
# GMT WORK_OF_ART
# Wednesday DATE
# 2,241.68 MONEY
# 40.4% PERCENT
# Reuters ORG
# 5.2% PERCENT
# 31,441.76 MONEY
# GMT WORK_OF_ART
# Monday DATE
# 1,552.78 MONEY
# 34.8% PERCENT
# year DATE
# Mexican NORP
# North London LOC
# a few weeks ago DATE
# +2779 PERSON
# May 24 DATE
# Reuters ORG
# its ninth week DATE
# today DATE
# Seth Green's PERSON
# NFT ORG
# two CARDINAL
# Seth Green's PERSON
# Nike ORG
# Seth Green's PERSON
# NFT ORG
# Sam Bankman-Fried PERSON
# the digital asset exchange ORG
# FTX ORG
# Riot Blockchain PERSON
# Marathon Digital Holdings ORG
# El Salvador GPE
# first ORDINAL
# September DATE
# $36 million MONEY
# over 50% PERCENT
# Thursday DATE
# May 30 DATE
# Reuters ORG
# Crypstation ORG
# HONG KONG GPE
# May 16 DATE
# Reuters ORG
# Monday DATE
# the weekend DATE
# European NORP
# Somalia PERSON
# U.S. GPE
# Sudan GPE
# five CARDINAL
# 05/13 Cryptocurrencies PERSON
# early Friday DATE
# TerraUSD ORG
# Warhol PERSON
# the week to May 13 DATE
# Olivia Chan PERSON
# May 24 DATE
# Reuters ORG
# first ORDINAL
# May 31 DATE
# Reuters ORG
# the United States GPE
# first ORDINAL
# SAN SALVADOR GPE
# NEW YORK GPE
# May 19 DATE
# Reuters ORG
# El Salvador's GPE
# Central American NORP
# September DATE
# recent weeks DATE
# May 16 DATE
# Reuters ORG
# FTX ORG
# Bitcoin ORG
# YouTube ORG
# Elon Musk PERSON
# YouTube ORG
# Ukraine GPE
# Fed ORG
# Reuters ORG
# June DATE
# Reuters ORG
# June DATE
# Musk PERSON
# U.S. GPE
# Joe Biden PERSON
# Musk PERSON
# Charley Cooper PERSON
# R3 GPE
# May 13 DATE
# Reuters ORG
# Central Africa's GPE
# Friday DATE
# weeks DATE
# the Central African Republic LOC
# May 24 DATE
# Reuters ORG
# One CARDINAL
# European Central Bank ORG
# NEW YORK GPE
# AP ORG
# a wild week DATE
# third ORDINAL
# May 13 DATE
# Reuters ORG
# Friday DATE
# 30,000 MONEY
# TerraUSD ORG
# LONDON GPE
# NEW YORK GPE
# May 12 DATE
# Reuters ORG
# one CARDINAL
# Thursday DATE
# Tether PERSON
# early Friday DATE
# TerraUSD ORG
# Tom Scally PERSON
# US GPE
# 37.84% PERCENT
# between September 2021 to January DATE
# the Cambridge Centre for Alternative ORG
# Luna PERSON
# TerraUSD ORG
# PayPal ORG
# today DATE
# U.S. GPE
# the bad old days DATE
# $59 million MONEY
# Miami GPE
# Bitcoin NORP
# Adam Masato PERSON
# 8,400 MONEY
# 342,000 MONEY
# 16% PERCENT
# August 2020 DATE
# 35-year-old DATE
# Adam Masato PERSON
# YouTube ORG
# Robuilt PERSON
# Joshua Tree PERSON
# California GPE
# Mas ORG
# Sam Bankman-Fried PERSON
# FTX ORG
# the Financial Times ORG
# the past several months DATE
# Gemini ORG
# Cameron PERSON
# Tyler Winklevoss PERSON
# Conservative Party ORG
# Pierre Poilievre PERSON
# Ottawa ORG
# 23 CARDINAL
# 16 CARDINAL
# one CARDINAL
# Bitcoin NORP
# 27,000 MONEY
# Thursday DATE
# morning TIME
# 2020 DATE
# one CARDINAL
# REUTERS ORG
# Dado Ruvic PERSON
# Christoph Huber PERSON
# Yossi Eliaz PERSON
# Muhammad S. Shamim PERSON
# David Weisz PERSON
# Goutham Seshadri PERSON
# Kevin Kim PERSON
# Shengqi Hang ORG
# Erez Lieberman PERSON
# May 31 DATE
# Reuters ORG
# Fidelity Investments' ORG
# this year DATE
# +1544 ORG
# HONG KONG GPE
# May 13 DATE
# Reuters ORG
# Nomura ORG
# 8604.T CARDINAL
# Friday DATE
# 2021 DATE
# European Central Bank ORG
# Christine Lagarde PERSON
# Saturday DATE
# January 2007 DATE
# Steve Jobs PERSON
# New York City GPE
# Reuters ORG
# More than 46,000 CARDINAL
# $1 billion MONEY
# 2021 DATE
# the Federal Trade Commission ORG
# FTC ORG
# Friday DATE
# Nearly half CARDINAL
# ORLANDO GPE
# Fla. GPE
# May 12 DATE
# Reuters ORG
# LONDON GPE
# May 25 DATE
# Reuters ORG
# three months DATE
# May 12 DATE
# Reuters ORG
# TerraUSD ORG
# Thursday DATE
# 2021 DATE
# 16 CARDINAL
# June 10 DATE
# Reuters ORG
# Canadians NORP
# Bank of Canada ORG
# Switzerland GPE
# May 23 DATE
# Reuters ORG
# year DATE
# Davos GPE
# Reuters ORG
# The New York State Legislature ORG
# two-year DATE
# Switzerland GPE
# May 23 DATE
# Reuters ORG
# Monday DATE
# 1 CARDINAL
# a wild week DATE
# third ORDINAL
# last week DATE
# Namthip Muanthongthae
# Investors ORG
# last week DATE
# recent days DATE
# Bitcoin ORG
# $3 trillion MONEY
# $1.2 trillion MONEY
# today DATE
# more than 19 CARDINAL
# Bitcoin ORG
# $3 trillion MONEY
# $1.2 trillion MONEY
# today DATE
# more than 19 CARDINAL
# WASHINGTON GPE
# May 17 DATE
# Reuters ORG
# Nofe Isah PERSON
# 25-year old DATE
# Nigeria GPE
# January DATE
# Last week DATE
# 5,000 MONEY
# +5652 ORG
# Tesla ORG
# Berlin GPE
# Germany GPE
# August 13, 2021 DATE
# Patrick Pleul/Pool PERSON
# Reuters ORG
# LONDON GPE
# May 12 DATE
# Reuters ORG
# the next year DATE
# NEW YORK GPE
# May 11 DATE
# Reuters ORG
# Coinbase Global WORK_OF_ART
# Bitcoin NORP
# May 25 DATE
# Reuters ORG
# Hong Kong GPE
# Babel Finance ORG
# Wednesday DATE
# $80 million MONEY
# $2 billion MONEY
# WASHINGTON GPE
# May 31 DATE
# Reuters ORG
# New York GPE
# $4.5 billion MONEY
# 2016 DATE
# Bitfinex ORG
# recent weeks DATE
# Bloomberg PERSON
# Kitco News ORG
# Terra ORG
# more than 97 percent PERCENT
# the past few days DATE
# UST ORG
# 2 cents MONEY
# early Thursday DATE
# 30% PERCENT
# 2020 DATE
# NFC CARDINAL
# The Bitcoin Note ORG
# Saturday DATE
# June DATE
# 4th
# Octagon Networks MONEY
# Bitcoin NORP
# as low as $8,000 MONEY
# Scott Minerd PERSON
# Guggenheim ORG
# 30,000 [dollars MONEY
# 8,000 [dollars MONEY
# Two-thirds CARDINAL
# Mike Novogratz PERSON
# Wednesday DATE
# Bloomberg PERSON
# first ORDINAL
# Galaxy Holdings ORG
# multibillion-dollar MONEY
# Coinbases ORG
# Brian Armstrong PERSON
# Dhara Ranasinghe ORG
# Friday 13 DATE
# LONDON GPE
# May 19 DATE
# Reuters ORG
# El Salvador GPE
# the International Monetary Fund ORG
# Moody's ORG
# June 7 DATE
# Reuters ORG
# Portugal GPE
# Benfica ORG
# first ORDINAL
# Socios.com ORG
# May 25 DATE
# Reuters ORG
# Israeli NORP
# StarkWare Industries ORG
# Wednesday DATE
# $100 million MONEY
# $8 billion MONEY
# Friday DATE
# a volatile week DATE
# US GPE
# Asian NORP
# European NORP
# Thursday DATE
# CoinDesk PRODUCT
# Austin GPE
# Dorsey's Block ORG
# Friday DATE
# 5 CARDINAL
# May DATE
# the start of the month DATE
# $600 billion MONEY
# 2020 DATE
# US GPE
# Friday DATE
# a losing week DATE
# Friday DATE
# six CARDINAL
# US GPE
# Friday DATE
# the week DATE
# the week DATE
# Dow ORG
# 2.1% PERCENT
# the S& ORG
# the American Precious Metals Exchange ORG
# Mike Segar/Reuters PERSON
# a rough week DATE
# February DATE

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_text = ' '.join(ether_df.text)
eth_text
# Out:
# 'GameStop has officially thrown itself headlong into the web3 vipers nest with a new app release, though its hard to say whether its proposed population of gamers and game developers will take up the … [+3255 chars] GameStop is going all-in on crypto. The video game retailer launched\xa0its own self-custodial Ethereum digital wallet, it said Monday. The wallet will be accessible through a Google Chrome extension an… [+1491 chars] The ability to conduct external transfers on PayPal\'s crypto platform, an image of which can be seen below, will start rolling out to users today and be available to everyone in the U.S. in the next … [+687 chars] A decentralized autonomous organization, or DAO, is giving away two seats on a Blue Origin flight to space.\r\nThis is likely the first time non-fungible tokens, or NFTs, have played a role in minting … [+4509 chars] Crypto Winter It May Be, But Ethereum Looks Like A Buy \r\nThe Winklevoss twins are cutting the staff at Gemini and say crypto winter is upon us. With the price of Ethereum (Cryptocurrency: ETH) down m… [+3614 chars] New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It\'s now bound for the desk of… [+2036 chars] DAVOS, Switzerland, May 25 (Reuters) - Ethereum\'s co-founder Gavin Wood said cryptocurrency investors need to be more aware of what is backing their holdings after a market rout which wiped more than… [+1744 chars] When Nvidia launched its Ampere Lite Hash Rate (LHR) graphics card with the feared Ethereum anti-mining limiter, the world knew it was only a matter of time before someone or a team cracked it. NiceH… [+1230 chars] May 11 (Reuters) - Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 40.4% fro… [+361 chars] June 6 (Reuters) - Bitcoin rose 5.2% to $31,441.76 at 2000 GMT on Monday, adding $1,552.78 to its previous close.\r\nThe world\'s biggest and best-known cryptocurrency is down 34.8% from the year\'s high… [+335 chars] [In a tweet] Buterin shared a paper by AI theorist and writer Eliezer Yudkowsky that made a case for why the current research community isn\'t doing enough to prevent a potential future catastrophe at… [+409 chars] YouTube is being criticised for failing to tackle a network of cyber-criminals streaming fake Elon Musk videos to scam viewers.\r\nThe criminals are hijacking YouTube accounts and using the videos to p… [+3851 chars] The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nThe craze has pushed total NFT sales volume to $29 billion ov… [+2866 chars] We first heard about the potential of blockchain in supply chains several years ago, and almost immediately were thrust into a cycle of hype and hope of what they could do for us, followed by a "trou… [+4785 chars] Every time you turn around, it seems another celebrity is hawking cryptocurrency or NFTs. Influencer Kim Kardashian, boxer Floyd Mayweather, and former NBA athlete Paul Pierce have all promoted Ether… [+2773 chars] NFT marketplaces are becoming the trend, and each and every one of them has started to build their own NFT marketplaces. \r\nHowever, few people require a marketplace that could be launched in the mark… [+5873 chars] Solana, the third largest cryptocurrency by market capitalization, fell 10% Wednesday following reports of its blockchain network suffering another outage.\xa0\r\nThe blockchain had not produced new block… [+566 chars] The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nThe craze has pushed total NFT sales volume to $29 billion ov… [+2830 chars] 6 with 6 posters participating\r\nNew York\'s state legislature approved a bill that would pr ...

# %%
# Run the NER processor on all of the text
eth_doc = nlp(eth_text)

# Add a title to the document
eth_doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GameStop
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has officially thrown itself headlong into the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     web3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  vipers nest with a new app release, though its hard to say whether its proposed population of gamers and game developers will take up the … [+3255 chars] GameStop is going all-in on crypto. The video game retailer launched its own self-custodial
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  digital wallet, it said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The wallet will be accessible through a
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google Chrome
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  extension an… [+1491 chars] The ability to conduct external transfers on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's crypto platform, an image of which can be seen below, will start rolling out to users
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and be available to everyone in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in the next … [+687 chars] A decentralized autonomous organization, or
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DAO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , is giving away
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  seats on a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blue Origin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>This is likely the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </br>The Winklevoss twins are cutting the staff at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gemini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and say crypto winter is upon us. With the price of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum (Cryptocurrency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : ETH) down m… [
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +3614
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br> mining operations. Early on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , state senators voted
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     36-27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  to pass the legislation. It's now bound for the desk of… [+2036 chars] DAVOS,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Switzerland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Ethereum's co-founder
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gavin Wood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said cryptocurrency investors need to be more aware of what is backing their holdings after a market rout which wiped more than… [+1744 chars] When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin

# %%
# List all Entities
for ent in eth_doc.ents:
    print(ent.text + ' ' + ent.label_)
# Out:
# GameStop ORG
# web3 LOC
# Ethereum ORG
# Monday DATE
# Google Chrome PRODUCT
# PayPal ORG
# today DATE
# U.S. GPE
# DAO ORG
# two CARDINAL
# Blue Origin ORG
# first ORDINAL
# Gemini ORG
# Ethereum (Cryptocurrency ORG
# +3614 NORP
# New York GPE
# Friday DATE
# 36-27 CARDINAL
# Switzerland GPE
# May 25 DATE
# Reuters ORG
# Gavin Wood PERSON
# Nvidia PERSON
# Ampere Lite Hash Rate WORK_OF_ART
# LHR ORG
# Ethereum ORG
# May 11 DATE
# Reuters ORG
# 7.23% PERCENT
# 28,758.29 MONEY
# GMT WORK_OF_ART
# Wednesday DATE
# 2,241.68 MONEY
# 40.4% PERCENT
# Reuters ORG
# 5.2% PERCENT
# 31,441.76 MONEY
# GMT WORK_OF_ART
# Monday DATE
# 1,552.78 MONEY
# 34.8% PERCENT
# year DATE
# Buterin PERSON
# AI ORG
# Eliezer Yudkowsky PERSON
# YouTube ORG
# Elon Musk PERSON
# YouTube ORG
# the past few years DATE
# NFT ORG
# $29 billion MONEY
# several years ago DATE
# Kim Kardashian PERSON
# Floyd Mayweather PERSON
# NBA ORG
# Paul Pierce PERSON
# Ether PERSON
# NFT ORG
# NFT ORG
# Solana PERSON
# third ORDINAL
# 10% PERCENT
# Wednesday DATE
# the past few years DATE
# NFT ORG
# $29 billion MONEY
# 6 CARDINAL
# 6 CARDINAL
# New York's GPE
# Ukraine GPE
# Ethereum ORG
# Johnny PERSON
# YouTuber ORG
# first ORDINAL
# Terras UST ORG
# 40 cents MONEY
# Alex Castro ORG
# a crushing few days DATE
# Terra PERSON
# a week DATE
# two CARDINAL
# Seth Green's PERSON
# Nike ORG
# a tough month DATE
# 25% PERCENT
# 30% PERCENT
# 81 MONEY
# a month ago DATE
# multibillion-dollar MONEY
# 1% PERCENT
# Bitcoin and Ethereum ORG
# first ORDINAL
# May 25 DATE
# Reuters ORG
# Hong Kong GPE
# Babel Finance ORG
# Wednesday DATE
# $80 million MONEY
# $2 billion MONEY
# one CARDINAL
# REUTERS ORG
# Dado Ruvic PERSON
# GamesBeat Summit 2022 ORG
# Kongregate PERSON
# George Soros' PERSON
# the
# Federal Reserve ORG
# Jack Dorsey PERSON
# Twitter ORG
# Conservative Party ORG
# Pierre Poilievre PERSON
# Ottawa ORG
# thousands CARDINAL
# The European Central Bank ORG
# UK GPE
# US GPE
# China GPE
# India GPE
# MetaMask PRODUCT
# DAO ORG
# Ethereum ORG
# MetaMask PRODUCT
# Consensys ORG
# Joseph Lubin PERSON
# Digital ORG
# last week DATE
# Tether PERSON
# as low as $0.94 MONEY
# Thursday DATE
# 0.9 MONEY
# Algorand GPE
# Algorand GPE
# 2017 DATE
# Silvio Micali PERSON
# Massachusett PERSON
# May DATE
# the start of the month DATE
# $600 billion MONEY
# 2020 DATE
# 3.0 CARDINAL
# third ORDINAL
# Tim Berners-Lee PERSON
# the past several months DATE
# Gemini ORG
# Cameron PERSON
# Tyler Winklevoss PERSON
# 23 CARDINAL
# 16 CARDINAL
# one CARDINAL
# Bitcoin NORP
# 27,000 MONEY
# Thursday DATE
# morning TIME
# 2020 DATE
# SQL ORG
# Alex Castro PERSON
# Verge ORG
# $11 million MONEY
# Switzerland GPE
# May 23 DATE
# May 30 DATE
# Reuters ORG
# Crypstation ORG
# multibillion-dollar MONEY
# Coinbases ORG
# Brian Armstrong PERSON
# weekly DATE
# Thursday DATE
# Frances Yue PERSON
# MarketWatch ORG
# Ill ORG
# Kraken ORG
# Kraken Pro PERSON
# America GPE
# Justice Department ORG
# first ORDINAL
# U.S. GPE
# the Washington Post ORG
# Jack Rosenthal PERSON
# 8 years old DATE
# 5,000 MONEY
# last week DATE
# Namthip Muanthongthae
# Investors ORG
# last week DATE
# Thursday DATE
# US GPE
# last month DATE
# Crypto.com Pay ORG
# Crypto.com ORG
# 0.5% PERCENT
# recent weeks DATE
# Bloomberg PERSON
# Cybersecurity Dive
#  ORG
# daily DATE
# Matt Miller PERSON
# Paul Sweeney PERSON
# Bloomberg Opinion ORG
# Bloomberg Intelligence PERSON
# Bitcoin PERSON
# first ORDINAL
# PayPal ORG
# Peter Thiel PERSON
# -21.76% PERCENT
# The Crypto Show WORK_OF_ART
# PayPal ORG
# Bitcoin NORP
# almost 20% PERCENT
# the past ten days DATE
# Reuters ORG
# June DATE
# Reuters ORG
# June DATE
# ] Neal Stephenson PERSON
# 1992 DATE
# Snow Crash PERSON
# first ORDINAL
# Thursday DATE
# Stephenson PERSON
# first ORDINAL
# NFT ORG
# Neophyte MMXXII #94 WORK_OF_ART
# Ster PERSON
# Tether ORG
# years DATE
# year DATE
# 2021 DATE
# Ethereum(ETH 0.49% ORG
# a rough few months DATE
# November DATE
# more than 60% PERCENT
# roughly $1,800 MONEY
# two CARDINAL
# around 2017 DATE
# a few years DATE
# the Ethereum Blockchain ORG
# DeFi LOC
# -1.64% PERCENT
# Ethereum(ETH -2.82% PERCENT
# two CARDINAL
# Cryptocurrencies ORG
# Ethereum(ETH -7.49% ORG
# more than 60% PERCENT
# Rune Christensen PERSON
# MakerDao ORG
# May 31 DATE
# This week DATE
# the past five years DATE
# 10.54% PERCENT
# 2,560% PERCENT
# Ava Labs PERSON
# -23.35% PERCENT
# The Crypto Show WORK_OF_ART
# April 20 DATE
# Fool.com ORG
# Ethereums ORG
# more than CARDINAL
# DeFi ORG
# 41% PERCENT
# $1.3 trillion MONEY
# year to date DATE
# Coinbase PRODUCT
# Coinbase Pro PERSON
# 16% PERCENT
# GameStop PRODUCT
# NFT ORG
# last week DATE
# VUCA ORG
# the late 1980s DATE
# the U.S. Army War College ORG
# recent quarter DATE
# 2.2 million CARDINAL
# second ORDINAL
# Ethereum ORG
# 3.16% PERCENT
# Today DATE
# This year DATE
# Solana ORG
# 78% PERCENT
# year DATE
# Bear ORG
# NEW YORK GPE
# AP ORG
# a wild week DATE
# third ORDINAL
# Ponzi ORG
# Crypto PERSON
# Seth Green's PERSON
# four CARDINAL
# Green ORG
# more than $300 MONEY
# second ORDINAL
# today DATE
# the Federal Reserve's ORG
# today DATE
# this afternoon TIME
# this week DATE
# Friday DATE
# U.S. GPE
# Thursday DATE
# Tuesday DATE
# -27.17% PERCENT
# U.S. GPE
# -6.01% PERCENT
# 10.51% PERCENT
# Ether GPE

# %% [markdown]
# ---
